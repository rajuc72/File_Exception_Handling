# %% [markdown]
# #File and Exception handling

# %% [markdown]
# 1.What is the difference between interpreted and compiled languages*
#
# Ans: The main difference between compiled languages and interpreted language is lies in executing/running the program. If the program contains error/s the compiled language wont execute the whole program , while in interpreted languages the program executes until the error/s occurs.
#
# 2.What is exception handling in Python?
#
# Ans: In simple words exception handling is a way of communicating with the compiler how to treat the block of code even if there are errors , and to know the exact error description .
#
# 3.What is the purpose of the finally block in exception handling?
#
# Ans: The Final block executed in all situations irrespective of the error messages or logging issues.
#
# 4.What is logging in Python*
#
# Ans: Logging is a mechanism to know the program status , in other words. Python logging is a module that allows you to track events that occur while your program is running.
#
#
# 5.What is the significance of the   deI	 method in Python*
#
# Ans:  In Python everything is an object, method  __del__ is a finalizer. It is called when an object is garbage collected which happens at some point after all references to the object have been deleted.
#
# 6.What is the difference between import and from ... import in Python*
#
# Ans: import meaning loading whole package/library files , on the other hand from…import means loading necessary packages or modules from that library.
#
# 7.How can you handle multiple exceptions in Python*
#
# Ans: Using try-Catch all block , like below
# try:
#     # code that may raise multiple exceptions
# except ValueError:
#     # handle ValueError
# except TypeError:
#     # handle TypeError
# except Exception as e:
#     # handle other exceptions
#     print(f"An error occurred: {e}")
#
#
# 8.What is the purpose of the with statement when handling files in Python*
#
# Ans: with statement simplifies file handling by automatically closing the file when the block of code is exited, even if an exception occurs.
#
# 9.What is the difference between multithreading and multiprocessing*
#
# Ans: Thread is nothing but processing a single unit of process, a process contains multiple threads. Multithreading uses multiple threads within the same process, sharing the same memory space and executes concurrently. .
# Multiprocessing uses multiple processes, each with its own memory space, allowing for true parallelism.
#
# 10.What are the advantages of using logging in a program?
#
# Ans: Logging helps track events, debug issues, record system activity, and monitor the application's behavior over time. It provides valuable insights for troubleshooting and maintaining software programs.
#
# 11.What is memory management in Python?
#
# Ans: Memory management in Python involves the allocation, deallocation, and reuse of memory to optimize the performance and efficiency of the program.
#
# 12.What are the basic steps involved in exception handling in Python*
#
# Ans:
# Try: Enclose the code that may raise an exception.
# Except: Handle the exception if it occurs.
# Else: Execute code if no exceptions are raised.
# Finally: Execute code regardless of whether an exception occurred or not.
#
# 13.Why is memory management important in Python?
#
# Ans: Memory management helps to maintain the memory efficiently. Like, with the help of garbage collection techniques we can deallocate or free-up the unwanted memory. So that we can allocate the same memory to other resources if needed.
#
# 14.What is the role of try and except in exception handling*
# Ans: The try block contains code that might raise an exception, while the except block contains code to handle the exception if it occurs.
#
# 15.How does Python's garbage collection system work*
#
# Ans: Python's garbage collection system automatically deallocates memory that is no longer in use.
#
# 16.What is the purpose of the else block in exception handling?
#
# Ans: The else block is executed if no exceptions are raised in the try block. It allows for clean execution of code that should only run if the try block is successful.
#
# 17.What are the common logging levels in Python*
#
# Ans: DEBUG: Detailed information of problem diagnosing.
# INFO: Confirmation that things are working as expected.
# WARNING: An indication that something unexpected happened or indicative of some problem in the near future.
# ERROR: A more serious problem, the software has not been able to perform some function.
# CRITICAL: A serious error, indicating that the program itself may be unable to continue running.
#
# 18.What is the difference between os.fork() and multiprocessing in Python*
#
# Ans:os.fork () Creates a new process by duplicating the current process. It’s limited to Unix-like operating systems.Multiprocessing allows creating and managing multiple processes across different operating systems.
#
# 19.What is the importance of closing a file in Python*
#
# Ans:Closing a file ensures that the system resources are released, and any buffered data is written to the file and to save the file.
#
# 20.What is the difference between file.read() and file.readIine() in Python*
#
# Ans: Read() method reads the whole content of the file a string  all at one go. The Readline method reads a single line at a time.
#
# 21.What is the logging module in Python used for*
#
# Ans: The logging module is used to track events that happen when some software runs. It allows for logging messages at different severity levels and helps in debugging and monitoring applications.
#
# 22.What is the os module in Python used for in file handling?
#
# Ans: The os module provides a way to interact with the operating system, including file handling operations like creating, removing, and checking the existence of files and directories.
#
# 23.What are the challenges associated with memory management in Python?
#
# Ans: Challenges include managing memory leaks, dealing with cyclic references, and ensuring efficient use of memory to avoid performance issues.
#
# 24.How do you raise an exception manually in Python?
#
# Ans: raise Exception("This is a custom exception message")
#
# 25.Why is it important to use multithreading in certain applications?
#
# Ans: Multithreading is important in applications that require concurrent execution, such as handling multiple I/O-bound tasks, to improve performance and responsiveness.

# %% [markdown]
# # Practical Questions in File operations and Exception handling

# %%
#1.How can you open a file for writing in Python and write a string to it?
with open("file.txt", "w") as file:
    file.write("Hello, world!")

#2.Write a Python program to read the contents of a file and print each line.
with open("file.txt", "r") as file:
    for line in file:
        print(line.strip())

#3.How would you handle a case where the file doesn't exist while trying to open it for reading*
try:
    with open("nonexistent_file.txt", "r") as file:
        content = file.read()
except FileNotFoundError:
    print("The file does not exist.")

#4.Write a Python script that reads from one file and writes its content to another file.
with open("source_file.txt", "r") as source_file:
  content = source_file.read()

with open("destination_file.txt", "w") as destination_file:
    destination_file.write(content)

#5.How would you catch and handle division by zero error in Python*
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Division by zero.")

#6.Write a Python program that logs an error message to a log file when a division by zero exception occurs.
import logging
logging.basicConfig(filename='app.log', level=logging.ERROR)
try:
    result = 10 / 0
except ZeroDivisionError:
    logging.error("Division by zero occurred.")

#7.How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?
import logging
logging.basicConfig(level=logging.INFO)
logging.info("This is an informational message.")
logging.warning("This is a warning message.")

#8.Write a program to handle a file opening error using exception handling.
try:
    with open("nonexistent_file.txt", "r") as file:
        content = file.read()
except FileNotFoundError:
    print("Error: The file does not exist.")

#9.How can you read a file line by line and store its content in a list in Python?
file_content=[]
with open('file.txt', 'r') as file:
    lines = file.readlines()
for line in lines:
    file_content.append(line.strip())
print(file_content)

#10.How can you append data to an existing file in Python?
with open("file.txt", "a") as file:
    file.write("This is appended data.")

#11.Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.
data = {'name': 'Alice'}
try:
    value = data['age']
except KeyError:
    print("Key not found.")

#12.Write a program that demonstrates using multiple except blocks to handle different types of exceptions.
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Division by zero.")
except ValueError:
    print("Error: Invalid value.")

#13.How would you check if a file exists before attempting to read it in Python?
import os
file_path = "file.txt"
if os.path.exists(file_path):
    with open(file_path, "r") as file:
        content = file.read()
        print(content)

#14.Write a program that uses the logging module to log both informational and error messages.
import logging
logging.basicConfig(level=logging.INFO)
logging.info("This is an informational message.")
logging.error("This is an error message")

#15.Write a Python program that prints the content of a file and handles the case when the file is empty.
try:
    with open("file.txt", "r") as file:
        content = file.read()
        if content:
            print(content)
        else:
            print("The file is empty.")
#16.Demonstrate how to use memory profiling to check the memory usage of a small program.
# Install memory_profiler with: pip install memory_profiler
from memory_profiler import profile

@profile
def my_function():
    a = [1] * (10**6)
    b = [2] * (2 * 10**7)
    del b
    return a

my_function()

#17.Write a Python program to create and write a list of numbers to a file, one number per line.
with open("numbers.txt", "w") as file:
    numbers = [1, 2, 3, 4, 5]
    for number in numbers:
        file.write(str(number) + "\n")

#18.How would you implement a basic logging setup that logs to a file with rotation after 1MB?
import logging
from logging.handlers import RotatingFileHandler

logger = logging.getLogger("my_logger")
logger.setLevel(logging.INFO)

#19.Write a program that handles both IndexError and KeyError using a try-except block.
my_list = [1, 2, 3]
my_dict = {'a': 1, 'b': 2}

try:
    value = my_list[5]
    value = my_dict['c']
except IndexError:
    print("IndexError: Index out of range.")
except KeyError:
    print("KeyError: Key not found in the dictionary.")

#20.How would you open a file and read its contents using a context manager in Python?
with open('file.txt', 'r') as file:
    content = file.read()
    print(content)

#21.Write a Python program that reads a file and prints the number of occurrences of a specific word.
def count_word_occurrences(file_path, word):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            word_count = content.lower().count
            print(f"The word '{word}' appears {word_count} times in the file.")
    except FileNotFoundError:
        print(f"File '{file_path}' not found.")

#22.How can you check if a file is empty before attempting to read its contents?
def is_file_empty(file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            if not content.strip():
                return True
            else:
                return False
                except FileNotFoundError:
        print(f"File '{file_path}' not found.")

#23.Write a Python program that writes to a log file when an error occurs during file handling.
import logging

logging.basicConfig(filename='error.log', level=logging.ERROR)

try:
    with open('nonexistent_file.txt', 'r') as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    logging.error("File not found during file handling.")
# Out:
# Hello, world!
# The file does not exist.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-4519de469bc8> in <cell line: 18>()
#      16
#      17 #4.Write a Python script that reads from one file and writes its content to another file.
# ---> 18 with open("source_file.txt", "r") as source_file:
#      19   content = source_file.read()
#      20
#
# FileNotFoundError: [Errno 2] No such file or directory: 'source_file.txt'
